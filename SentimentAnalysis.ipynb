# %% [markdown]
# <a href="https://colab.research.google.com/github/nityam0703/ChatGPTSentiment_Analysis/blob/main/SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries for reading data and performing eda
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/file.csv')

# %% [markdown]
# **UNDERSTANDING DATA AND HANDLING MISSING/ DUPLICATES IF ANY**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219294 entries, 0 to 219293
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  219294 non-null  int64
#  1   tweets      219294 non-null  object
#  2   labels      219294 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ MB

# %%
df.describe().T
# Out:
#                count      mean           std  min       25%       50%  \
# Unnamed: 0  219294.0  109646.5  63304.869303  0.0  54823.25  109646.5
#
#                   75%       max
# Unnamed: 0  164469.75  219293.0

# %%
df.head()
# Out:
#    Unnamed: 0                                             tweets   labels
# 0           0  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 1           1  Try talking with ChatGPT, our new AI system wh...     good
# 2           2  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 3           3  THRILLED to share that ChatGPT, our new model ...     good
# 4           4  As of 2 minutes ago, @OpenAI released their ne...      bad

# %%
df.isnull().sum().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of Unnamed: 0    0
# tweets        0
# labels        0
# dtype: int64>

# %%
df.drop_duplicates()
# Out:
#         Unnamed: 0                                             tweets   labels
# 0                0  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 1                1  Try talking with ChatGPT, our new AI system wh...     good
# 2                2  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 3                3  THRILLED to share that ChatGPT, our new model ...     good
# 4                4  As of 2 minutes ago, @OpenAI released their ne...      bad
# ...            ...                                                ...      ...
# 219289      219289  Other Software Projects Are Now Trying to Repl...      bad
# 219290      219290  I asked #ChatGPT to write a #NYE Joke for SEOs...     good
# 219291      219291  chatgpt is being disassembled until it can onl...      bad
# 219292      219292  2023 predictions by #chatGPT. Nothing really s...      bad
# 219293      219293   From ChatGPT, neat stuff https://t.co/qjjUF2Z2m0  neutral
#
# ...

# %%
df.drop(['Unnamed: 0'], axis=1,inplace = True)

# %%
df.head()
# Out:
#                                               tweets   labels
# 0  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 1  Try talking with ChatGPT, our new AI system wh...     good
# 2  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 3  THRILLED to share that ChatGPT, our new model ...     good
# 4  As of 2 minutes ago, @OpenAI released their ne...      bad

# %% [markdown]
# **EDA on Label Column**
